# %%
from random import random
from random import seed
import numpy as np
import pandas as pd
from keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# (X_train, Y_train), (X_test, Y_test) = mnist.load_data()
# normalization
# x_train = X_train.reshape(60000,784)/255
# x_test = X_test.reshape(10000,784)/255
# label_train = to_categorical(Y_train)
# label_test = to_categorical(Y_test)
# print(label_train[0,:].shape)

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
x_train = X_train.reshape(60000,28, 28,1)/255
x_test = X_test.reshape(10000, 28, 28,1)/255
x_train = x_train.reshape(60000,-1)
x_test = x_test.reshape(10000,-1)
y_train = pd.get_dummies(Y_train).to_numpy()
y_test = pd.get_dummies(Y_test).to_numpy()
print('Train features',x_train.shape,'train labels',y_train.shape)
print('Test features',x_test.shape,'test labels',y_test.shape)
# Out:
# Train features (60000, 784) train labels (60000, 10)
# Test features (10000, 784) test labels (10000, 10)

# %%
def initialize_network(n_inputs, n_hidden, n_outputs):
    layer1 = np.random.randn(n_hidden,n_inputs+1)/10
    layer2 = np.random.randn(n_outputs,n_hidden+1)/10
    return layer1, layer2

def weighted_sum(weights, inputs):
    inputs = np.append(inputs,[1])
    inputs = inputs.reshape((len(inputs),1))
    outputs = weights.dot(inputs)
    return outputs

def sigmoid(activation):
    return 1.0 / (1.0 + np.exp(-activation))

def sigmoid_derivative(output): #原本的output 要在乘上sigmoid 在乘上
    return sigmoid(output) * (1.0 - sigmoid(output)) 

def MSE(label, train):
    error = label - train
    error = np.square(error)
    error = np.sum(error)
    return 0.5*error

def MSE2(y,y_hat):
    err_avg = np.sum((y_hat-y)**2,axis=1)
    return sum(err_avg)/y_hat.shape[0]

def MSE_derivative(label, train):
    return label - train

def forward_propagate(layer1, layer2, inputs):
    output0 = weighted_sum(layer1, inputs)      # layer1 還沒經過 activate function
    output1 = sigmoid(output0)                  # layer1 經過 activate function
    output4 = weighted_sum(layer2, output1)     # layer2 還沒經過 activate function
    output2 = sigmoid(output4)                  # layer2 經過 activate function
    return output1, output2, output0, output4
# ------------------------------------------- 批量輸出 ------------------------------------ # 
def net_output(layer1, layer2, inputs):
    inputs = np.concatenate((inputs,np.ones(inputs.shape[0]).reshape(-1,1)), axis=1) 
    output1 = sigmoid(layer1.dot(inputs.T))   
    output1 = np.concatenate((output1,np.ones(output1.shape[1]).reshape(1,-1)),axis=0)
    output2 = sigmoid(layer2.dot(output1))                  
    return output2

def backward_propagate(layer1, layer2, output1, output2, output0, output4, ln_rate, inputs, label):
    #delta2
    error2 = MSE_derivative(label, output2)*sigmoid_derivative(output4)
    error2 = error2.reshape((len(error2),1))
    output1 = np.append(output1,[1])
    output1 = output1.reshape((1,len(output1)))
    delta2 = ln_rate*error2.dot(output1)
    #delta1
    error1 = error2.reshape((1,len(output2))).dot(layer2)
    error1 = np.delete(error1, len(error1)-1)
    error1 = error1.reshape((len(error1),1))
    error1 = error1*sigmoid_derivative(output0)
    inputs = np.append(inputs,[1])
    inputs = inputs.reshape((1,len(inputs)))
    delta1 = ln_rate*error1.dot(inputs)
    #Update weights
    layer1 = layer1 + delta1
    layer2 = layer2 + delta2
    return layer1, layer2

def mc_acc(yhat,y):
    y_hat = np.argmax(yhat,axis=1)
    yy = np.argmax(y,axis=1)
    return np.sum(np.equal(y_hat,yy))/len(yy)
    
def acc_multiclass(ee,epochs,layer1, layer2,x_train,x_test,y_train,y_test):
    y_te = net_output(layer1, layer2,x_test)
    tel = MSE2(y_te.T,y_test)
    
    y_tr = net_output(layer1, layer2,x_train)
    tl = MSE2(y_tr.T,y_train)
    
    ta = mc_acc(y_tr.T,y_train)
    tea = mc_acc(y_te.T,y_test)   
    
    print("Epoch",ee+1,"/",epochs,"- loss: %.4f" %tl,"- accuracy: %.4f" %ta,
        "- test_loss: %.4f" %tel,"- test_accuracy: %.4f" %tea)            
    return tl, ta, tel, tea

def train_network(layer1, layer2, x_train, y_train, x_test, y_test, ln_rate, epoch, batch_size):
    loss = []
    accuracy = []
    test_loss = []
    test_accuracy = []
    for ee in range(epoch):
        for index,x_dd in enumerate(x_train):
            output1, output2, output0, output4 = forward_propagate(layer1, layer2, x_dd)
            layer1, layer2 = backward_propagate( layer1, layer2, output1, output2, output0, output4, ln_rate, x_dd ,label=y_train[index].reshape(-1,1))     
            
        tl, ta, tel, tea = acc_multiclass(ee,epoch,layer1, layer2,x_train,x_test,y_train,y_test)
        loss.append(tl)
        accuracy.append(ta)
        test_loss.append(tel)
        test_accuracy.append(tea)
        
    return layer1, layer2, loss, accuracy, test_loss, test_accuracy

# %%
# Model accuracy with sigmoid and lr=0.01
layer1, layer2 = initialize_network(784,128,10)
ln_rate = 0.01
epoch = 40
batch_size = 1
layer1, layer2, loss, accuracy, test_loss, test_accuracy = train_network(layer1, layer2, x_train, y_train, x_test, y_test, ln_rate, epoch, batch_size)

x = []
for i in range(epoch):
    x.append(i+1)

plt.title("Model accuracy with sigmoid and lr=0.01") 
plt.xlabel("Epoch") 
plt.ylabel("Accurary")
plt.plot(x,accuracy,'-',color='red',label='Train')
plt.plot(x,test_accuracy,'-',color='blue',label='Val')
plt.legend(loc='upper left', shadow=True)
# Out:
# Epoch 1 / 40 - loss: 0.2544 - accuracy: 0.8650 - test_loss: 0.2431 - test_accuracy: 0.8761
# Epoch 2 / 40 - loss: 0.1917 - accuracy: 0.8934 - test_loss: 0.1823 - test_accuracy: 0.9030
# Epoch 3 / 40 - loss: 0.1661 - accuracy: 0.9070 - test_loss: 0.1584 - test_accuracy: 0.9122
# Epoch 4 / 40 - loss: 0.1502 - accuracy: 0.9154 - test_loss: 0.1437 - test_accuracy: 0.9189
# Epoch 5 / 40 - loss: 0.1385 - accuracy: 0.9221 - test_loss: 0.1332 - test_accuracy: 0.9250
# Epoch 6 / 40 - loss: 0.1291 - accuracy: 0.9273 - test_loss: 0.1249 - test_accuracy: 0.9293
# Epoch 7 / 40 - loss: 0.1214 - accuracy: 0.9318 - test_loss: 0.1180 - test_accuracy: 0.9334
# Epoch 8 / 40 - loss: 0.1147 - accuracy: 0.9357 - test_loss: 0.1121 - test_accuracy: 0.9377
# Epoch 9 / 40 - loss: 0.1089 - accuracy: 0.9389 - test_loss: 0.1071 - test_accuracy: 0.9404
# Epoch 10 / 40 - loss: 0.1038 - accuracy: 0.9418 - test_loss: 0.1027 - test_accuracy: 0.9429
# Epoch 11 / 40 - loss: 0.0991 - accuracy: 0.9449 - test_loss: 0.0988 - test_accuracy: 0.9437
# Epoch 12 / 40 - loss: 0.0949 - accuracy: 0.9473 - test_loss: 0.0954 - test_accuracy: 0.9449
# Epoch 13 / 40 - loss: 0.0911 - accuracy: 0.9493 - test_loss: 0.0922 - test_accuracy: 0.9472
# Epoch 14 / 40 - loss: 0.0876 - accuracy: 0.9514 - test_loss: 0.0894 - test_accuracy: 0.9488
# Epoch 15 / 40 - loss: 0.0844 - accuracy: 0.9532 - test_loss: 0.0868 - test_accuracy: 0.9503
# Epoch 16 / 40 - loss: 0.0815 - accuracy: 0.9554 - test_loss: 0.0844 - test_accuracy: 0.9528
# Epoch 17 / 40 - loss: 0.0789 - accuracy: 0.9569 - test_loss: 0.0823 - test_accuracy: 0.9543
# Epoch 18 / 40 - loss: 0.0764 - accuracy: 0.9586 - test_loss: 0.0803 - test_accuracy: 0.9554
# Epoch 19 / 40 - loss: 0.0741 - accuracy: 0.9598 - test_loss: 0.0785 - test_accuracy: 0.9565
# Epoch 20 / 40 - loss: 0.0720 - accuracy: 0.9612 - test_loss: 0.0768 - test_accuracy: 0.9578
# Epoch 21 / 40 - loss: 0.0700 - accuracy: 0.9622 - test_loss: 0.0752 - test_accuracy: 0.9591
# Epoch 22 / 40 - loss: 0.0682 - accuracy: 0.9634 - test_loss: 0.0737 - test_accuracy: 0.9604
# Epoch 23 / 40 - loss: 0.0664 - accuracy: 0.9645 - test_loss: 0.0724 - test_accuracy: 0.9615
# Epoch 24 / 40 - loss: 0.0648 - accuracy: 0.9654 - test_loss: 0.0711 - test_accuracy: 0.9622
# Epoch 25 / 40 - loss: 0.0632 - accuracy: 0.9661 - test_loss: 0.0698 - test_accuracy: 0.9635
# Epoch 26 / 40 - loss: 0.0617 - accuracy: 0.9670 - test_loss: 0.0687 - test_accuracy: 0.9640
# Epoch 27 / 40 - loss: 0.0603 - accuracy: 0.9678 - test_loss: 0.0675 - test_accuracy: 0.9642
# Epoch 28 / 40 - loss: 0.0590 - accuracy: 0.9686 - test_loss: 0.0665 - test_accuracy: 0.9647
# Epoch 29 / 40 - loss: 0.0578 - accuracy: 0.9694 - test_loss: 0.0655 - test_accuracy: 0.9650
# Epoch 30 / 40 - loss: 0.0565 - accuracy: 0.9702 - test_loss: 0.0645 - test_accuracy: 0.9655
# Epoch 31 / 40 - loss: 0.0554 - accuracy: 0.9709 - test_loss: 0.0637 - test_accuracy: 0.9659
# Epoch 32 / 40 - loss: 0.0543 - accuracy: 0.9717 - test_loss: 0.0628 - test_accuracy: 0.9663
# Epoch 33 / 40 - loss: 0.0532 - accuracy: 0.9724 - test_loss: 0.0620 - test_accuracy: 0.9669
# Epoch 34 / 40 - loss: 0.0522 - accuracy: 0.9732 - test_loss: 0.0612 - test_accuracy: 0.9672
# Epoch 35 / 40 - loss: 0.0512 - accuracy: 0.9738 - test_loss: 0.0605 - test_accuracy: 0.9676
# Epoch 36 / 40 - loss: 0.0503 - accuracy: 0.9742 - test_loss: 0.0598 - test_accuracy: 0.9681
# Epoch 37 / 40 - loss: 0.0494 - accuracy: 0.9748 - test_loss: 0.0592 - test_accuracy: 0.9684
# Epoch 38 / 40 - loss: 0.0485 - accuracy: 0.9754 - test_loss: 0.0586 - test_accuracy: 0.9687
# Epoch 39 / 40 - loss: 0.0476 - accuracy: 0.9759 - test_loss: 0.0580 - test_accuracy: 0.9691
# Epoch 40 / 40 - loss: 0.0468 - accuracy: 0.9763 - test_loss: 0.0574 - test_accuracy: 0.9695

# %%
plt.title("Model Loss with sigmoid and lr=0.01") 
plt.xlabel("Epoch") 
plt.ylabel("Loss")
plt.plot(x,loss,'-',color='red',label='Train')
plt.plot(x,test_loss,'-',color='blue',label='Val')
plt.legend(loc='upper left', shadow=True)

# %%
# Model accuracy with sigmoid and lr=0.1
layer1, layer2 = initialize_network(784,128,10)
ln_rate = 0.1
epoch = 40
batch_size = 1
layer1, layer2, loss, accuracy, test_loss, test_accuracy = train_network(layer1, layer2, x_train, y_train, x_test, y_test, ln_rate, epoch, batch_size)

x = []
for i in range(epoch):
    x.append(i+1)
plt.title("Model accuracy with sigmoid and lr=0.1") 
plt.xlabel("Epoch") 
plt.ylabel("Accurary")
plt.plot(x,accuracy,'-',color='red',label='Train')
plt.plot(x,test_accuracy,'-',color='blue',label='Val')
plt.legend(loc='upper left', shadow=True)
# Out:
# Epoch 1 / 40 - loss: 0.1184 - accuracy: 0.9313 - test_loss: 0.1155 - test_accuracy: 0.9318
# Epoch 2 / 40 - loss: 0.0842 - accuracy: 0.9532 - test_loss: 0.0871 - test_accuracy: 0.9507
# Epoch 3 / 40 - loss: 0.0675 - accuracy: 0.9634 - test_loss: 0.0738 - test_accuracy: 0.9593
# Epoch 4 / 40 - loss: 0.0576 - accuracy: 0.9695 - test_loss: 0.0662 - test_accuracy: 0.9641
# Epoch 5 / 40 - loss: 0.0502 - accuracy: 0.9740 - test_loss: 0.0608 - test_accuracy: 0.9678
# Epoch 6 / 40 - loss: 0.0447 - accuracy: 0.9774 - test_loss: 0.0571 - test_accuracy: 0.9696
# Epoch 7 / 40 - loss: 0.0407 - accuracy: 0.9799 - test_loss: 0.0549 - test_accuracy: 0.9701
# Epoch 8 / 40 - loss: 0.0376 - accuracy: 0.9816 - test_loss: 0.0535 - test_accuracy: 0.9715
# Epoch 9 / 40 - loss: 0.0352 - accuracy: 0.9827 - test_loss: 0.0525 - test_accuracy: 0.9729
# Epoch 10 / 40 - loss: 0.0329 - accuracy: 0.9839 - test_loss: 0.0517 - test_accuracy: 0.9729
# Epoch 11 / 40 - loss: 0.0309 - accuracy: 0.9851 - test_loss: 0.0509 - test_accuracy: 0.9735
# Epoch 12 / 40 - loss: 0.0293 - accuracy: 0.9859 - test_loss: 0.0506 - test_accuracy: 0.9735
# Epoch 13 / 40 - loss: 0.0281 - accuracy: 0.9866 - test_loss: 0.0507 - test_accuracy: 0.9739
# Epoch 14 / 40 - loss: 0.0272 - accuracy: 0.9875 - test_loss: 0.0510 - test_accuracy: 0.9730
# Epoch 15 / 40 - loss: 0.0261 - accuracy: 0.9880 - test_loss: 0.0510 - test_accuracy: 0.9728
# Epoch 16 / 40 - loss: 0.0246 - accuracy: 0.9887 - test_loss: 0.0505 - test_accuracy: 0.9727
# Epoch 17 / 40 - loss: 0.0232 - accuracy: 0.9892 - test_loss: 0.0497 - test_accuracy: 0.9728
# Epoch 18 / 40 - loss: 0.0219 - accuracy: 0.9897 - test_loss: 0.0490 - test_accuracy: 0.9737
# Epoch 19 / 40 - loss: 0.0208 - accuracy: 0.9899 - test_loss: 0.0485 - test_accuracy: 0.9737
# Epoch 20 / 40 - loss: 0.0199 - accuracy: 0.9905 - test_loss: 0.0482 - test_accuracy: 0.9740
# Epoch 21 / 40 - loss: 0.0190 - accuracy: 0.9908 - test_loss: 0.0479 - test_accuracy: 0.9744
# Epoch 22 / 40 - loss: 0.0183 - accuracy: 0.9910 - test_loss: 0.0477 - test_accuracy: 0.9746
# Epoch 23 / 40 - loss: 0.0177 - accuracy: 0.9915 - test_loss: 0.0476 - test_accuracy: 0.9744
# Epoch 24 / 40 - loss: 0.0171 - accuracy: 0.9918 - test_loss: 0.0475 - test_accuracy: 0.9747
# Epoch 25 / 40 - loss: 0.0167 - accuracy: 0.9922 - test_loss: 0.0475 - test_accuracy: 0.9753
# Epoch 26 / 40 - loss: 0.0162 - accuracy: 0.9924 - test_loss: 0.0475 - test_accuracy: 0.9756
# Epoch 27 / 40 - loss: 0.0156 - accuracy: 0.9928 - test_loss: 0.0475 - test_accuracy: 0.9757
# Epoch 28 / 40 - loss: 0.0151 - accuracy: 0.9930 - test_loss: 0.0474 - test_accuracy: 0.9760
# Epoch 29 / 40 - loss: 0.0147 - accuracy: 0.9931 - test_loss: 0.0474 - test_accuracy: 0.9767
# Epoch 30 / 40 - loss: 0.0143 - accuracy: 0.9932 - test_loss: 0.0473 - test_accuracy: 0.9763
# Epoch 31 / 40 - loss: 0.0138 - accuracy: 0.9934 - test_loss: 0.0471 - test_accuracy: 0.9764
# Epoch 32 / 40 - loss: 0.0134 - accuracy: 0.9936 - test_loss: 0.0470 - test_accuracy: 0.9767
# Epoch 33 / 40 - loss: 0.0130 - accuracy: 0.9938 - test_loss: 0.0470 - test_accuracy: 0.9766
# Epoch 34 / 40 - loss: 0.0126 - accuracy: 0.9939 - test_loss: 0.0469 - test_accuracy: 0.9769
# Epoch 35 / 40 - loss: 0.0122 - accuracy: 0.9941 - test_loss: 0.0468 - test_accuracy: 0.9772
# Epoch 36 / 40 - loss: 0.0118 - accuracy: 0.9941 - test_loss: 0.0467 - test_accuracy: 0.9771
# Epoch 37 / 40 - loss: 0.0114 - accuracy: 0.9942 - test_loss: 0.0466 - test_accuracy: 0.9770
# Epoch 38 / 40 - loss: 0.0111 - accuracy: 0.9943 - test_loss: 0.0465 - test_accuracy: 0.9770
# Epoch 39 / 40 - loss: 0.0108 - accuracy: 0.9944 - test_loss: 0.0465 - test_accuracy: 0.9772
# Epoch 40 / 40 - loss: 0.0105 - accuracy: 0.9946 - test_loss: 0.0465 - test_accuracy: 0.9774

# %%
plt.title("Model Loss with sigmoid and lr=0.1") 
plt.xlabel("Epoch") 
plt.ylabel("Loss")
plt.plot(x,loss,'-',color='red',label='Train')
plt.plot(x,test_loss,'-',color='blue',label='Val')
plt.legend(loc='upper left', shadow=True)
